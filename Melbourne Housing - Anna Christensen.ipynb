# %% [markdown]
# <a href="https://colab.research.google.com/github/annachristen/DA-Class-Notes-and-projects/blob/main/Melbourne%20Housing%20-%20Anna%20Christensen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Melbourne, Australia's second-largest city, is known for its vibrant cultural scene, diverse population, and beautiful parks. It boasts iconic landmarks like Federation Square and the Royal Botanic Gardens, as well as a thriving coffee culture. Melbourne is famous for its sports passion, hosting events like the Australian Open and Melbourne Cup, making it a dynamic and cosmopolitan destination.
#
# Recently, the housing market in Melbourne has seen explosive growth. In this project, you will conduct an exploratory data analysis to analyze trends in the housing market and try to determine trends that might be useful to an investor.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('housing.csv')
df.head()
# Out:
#        Suburb          Address  Rooms   Type    Price               Method  \
# 0  Abbotsford  25 Bloomburg St      2  house  1035000        property sold
# 1  Abbotsford     5 Charles St      3  house  1465000  property sold prior
# 2  Abbotsford      55a Park St      4  house  1600000           vendor bid
# 3  Abbotsford     124 Yarra St      3  house  1876000        property sold
# 4  Abbotsford    98 Charles St      2  house  1636000        property sold
#
#   SellerG       Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  Biggin   4/2/2016       2.5      3067         2         1  0.0       156
# 1  Biggin   4/3/2017       2.5      3067         3         2  0.0       134
# 2  Nelson   4/6/2016       2.5      3067         3         1  2.0       120
# 3  Nelson   7/5/2016       2.5      3067         4         2  0.0       245
# 4  Nelson  8/10/2016       2.5      3067         2         1  2.0       256
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6847 entries, 0 to 6846
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         6847 non-null   object
#  1   Address        6847 non-null   object
#  2   Rooms          6847 non-null   int64
#  3   Type           6847 non-null   object
#  4   Price          6847 non-null   int64
#  5   Method         6847 non-null   object
#  6   SellerG        6847 non-null   object
#  7   Date           6847 non-null   object
#  8   Distance       6847 non-null   float64
#  9   Postcode       6847 non-null   int64
#  10  Bedroom2       6847 non-null   int64
#  11  Bathroom       6847 non-null   int64
#  12  Car            6819 non-null   float64
#  13  Landsize       6847 non-null   int64
#  14  BuildingArea   6847 non-null   float64
#  15  YearBuilt      6847 non-null   float64
#  16  CouncilArea    6187 non-null   object
# ...

# %% [markdown]
# 1. Create a scatter plot that shows land size on the x-axis and price on the y-axis. Change the color of the points to reflect the type of the property. Paste the image below.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Landsize', y='Price', data=df, size='Price', hue='Type' )
plt.show()

# %% [markdown]
# 2. In the graph created previously, two distinct patterns appear where one type of property experiences a price increase with just a slight increase in land size and another type of property experiences only small price increases as land size increases. Which type of property experiences a steep price increase as the land size goes up?

# %% [markdown]
# Answer - Unit

# %% [markdown]
# 3. Create a line chart that shows the year built along the x-axis and the average price per year on the y-axis. You will need to use aggregation and group by to accomplish this. Paste the image below.

# %%
avg_price_by_year = df.groupby('YearBuilt')['Price'].mean().reset_index()

# %%
plt.figure(figsize=(20, 4))
sns.lineplot(data=avg_price_by_year, x='YearBuilt', y='Price', marker='o')

plt.title('Average House Price by Year Built')
plt.xlabel('Year Built')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# 4. According to the line chart produce above, does the average price of properties seem to increase or decrease as the property becomes newer?

# %% [markdown]
# Answer - decrease as property becomes newer

# %% [markdown]
# 5. Create a bar chart that shows the region on the x-axis and the average price of the property on the y-axis. You will need to use aggregation and group by to accomplish this. Paste the image below.

# %%
PricebyRegion = df.groupby('Regionname')['Price'].mean().reset_index()

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=PricebyRegion, x='Regionname', y='Price')

plt.title('Average Property Price by Region')
plt.xlabel('Region')
plt.ylabel('Average Price')
# Out:
# Text(0, 0.5, 'Average Price')

# %% [markdown]
# 6. According to the bar chart above, properties appear to have the highest average price in which region?

# %% [markdown]
# Answer - Southern Metropolitan

# %% [markdown]
# 7. Create a histogram of property prices. Paste the image below.

# %%
plt.figure(figsize=(8, 3))
sns.histplot(x='Price', data=df)
plt.show()

# %% [markdown]
# 8. According to the histogram above, are the prices for properties right skewed, left skewed, or not skewed at all?

# %% [markdown]
# Answer - Right skewed

# %% [markdown]
# 9. Create a box plot that shows the years that each property was built on the x-axis and the region on the y-axis. These box plots should be oriented horizontally. Paste an image of the graphic below.

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data=df, x='YearBuilt', y='Regionname', orient='h')
plt.title('Distribution of Property Year Built by Region')
plt.xlabel('Year Built')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# 10. According to the box plot above, which region has properties built in the widest range of time?

# %% [markdown]
# Answer - Northern Metropolitan

# %% [markdown]
# 11. According to the box plot above, which region is the only region that has very few properties listed that were built after the year 2000?

# %% [markdown]
# Answer - Western Victoria
